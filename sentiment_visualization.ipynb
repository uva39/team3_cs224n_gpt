# %%
from run_visualizer import *

# %%
csv_files = [
    "reports/after_hyper-sweep/cfimdb_runs_sorted_by_acc.csv",
    "reports/after_hyper-sweep/cfimdb_runs_sorted_by_f1.csv",
    "reports/after_hyper-sweep/SST_runs_sorted_by_acc.csv",
    "reports/after_hyper-sweep/SST_runs_sorted_by_f1.csv",
]

df = load_and_prepare_runs(csv_files)
df.head()
# Out:
#     dataset   best_dev_acc         best_dev_f1          best_epoch  \
# 0   cfimdb              0.983673             0.983673          2.0
# 75   cfimdb                  NaN                  NaN          NaN
# 76   cfimdb                  NaN                  NaN          NaN
# 77   cfimdb                  NaN                  NaN          NaN
# 78   cfimdb                  NaN                  NaN          NaN
#
#      final_train_acc      final_train_f1       final_dev_acc       \
# 0              0.998243             0.998243              0.97551
# 75                  NaN                  NaN                  NaN
# 76                  NaN                  NaN                  NaN
# 77                  NaN                  NaN                  NaN
# 78                  NaN                  NaN                  NaN
#
#      final_dev_f1         fine_tune_mode       lr     ...  \
# 0              0.975507   full-model         0.00002  ...
# 75                  NaN                 NaN      NaN  ...
# 76                  NaN                 NaN      NaN  ...
# 77                  NaN                 NaN      NaN  ...
# 78                  NaN                 NaN      NaN  ...
#
#     simple_classifier_use  warmup_use  weight_decay_use grad_clip_use  \
# 0                  no use      no use            no use        no use
# 75                    use         use               use           use
# 76                    use         use               use           use
# 77                 no use         use               use           use
# 78                    use         use               use           use
#
#    scheduler_use          experiment_group        is_hyper_sweep  \
# 0         no use                   not use     manual experiment
# 75           use  hyper sweep: RDrop alpha  hyperparameter sweep
# 76           use    Rdrop-last-mean-simple     manual experiment
# 77           use       Rdrop-last-mean-mlp     manual experiment
# 78           use      hyperparameter sweep  hyperparameter sweep
#
#     is_base_model  model_role    acc_f1_gap
# 0           False      others           NaN
# 75          False  best model  2.720000e-07
# 76          False      others  2.720000e-07
# 77          False      others  2.720000e-07
# 78          False      others  0.000000e+00
#
# [5 rows x 77 columns]

# %%
run_default_visualizations(
    df,
    output_dir="plots",
    metric="best_dev_f1",
)
# Out:
# saved: plots/SST_model_role_scatter.png
# saved: plots/cfimdb_model_role_scatter.png
# skip cfimdb  / model_role: only one value
# saved: plots/SST_fine_tune_type_scatter.png
# saved: plots/cfimdb_fine_tune_type_scatter.png
# skip cfimdb  / fine_tune_type: only one value
# saved: plots/SST_experiment_group_scatter.png
# saved: plots/cfimdb_experiment_group_scatter.png
# skip cfimdb  / experiment_group: only one value
# saved: plots/SST_is_hyper_sweep_scatter.png
# saved: plots/cfimdb_is_hyper_sweep_scatter.png
# skip cfimdb  / is_hyper_sweep: only one value
# saved: plots/SST_rdrop_use_scatter.png
# saved: plots/cfimdb_rdrop_use_scatter.png
# skip cfimdb  / rdrop_use: only one value
# saved: plots/SST_warmup_use_scatter.png
# saved: plots/cfimdb_warmup_use_scatter.png
# skip cfimdb  / warmup_use: only one value
# saved: plots/SST_scheduler_use_scatter.png
# saved: plots/cfimdb_scheduler_use_scatter.png
# skip cfimdb  / scheduler_use: only one value
# saved: plots/SST_simple_classifier_use_scatter.png
# saved: plots/cfimdb_simple_classifier_use_scatter.png
# skip cfimdb  / simple_classifier_use: only one value
# saved: plots/SST_pooling_config_cat_scatter.png
# saved: plots/cfimdb_pooling_config_cat_scatter.png
# skip cfimdb  / pooling_config_cat: only one value
# saved: plots/SST_full_fine-tuning_top_10_best_dev_f1.png
# saved: plots/SST_last_layer_only_top_10_best_dev_f1.png
# saved: plots/cfimdb_full_fine-tuning_top_10_best_dev_f1.png
# saved: plots/cfimdb_last_layer_only_top_10_best_dev_f1.png
# saved: plots/SST_delta_from_base_best_dev_f1.png
# saved: plots/cfimdb_delta_from_base_best_dev_f1.png
# cfimdb : no base model rows
# saved: plots/SST_lr_best_dev_f1_sweep.png
# saved: plots/cfimdb_lr_best_dev_f1_sweep.png
# skip cfimdb  / lr: only one value
# saved: plots/SST_hidden_dropout_prob_best_dev_f1_sweep.png
# skip cfimdb / hidden_dropout_prob: only one value
# skip cfimdb  / hidden_dropout_prob: only one value
# saved: plots/SST_rdrop_alpha_best_dev_f1_sweep.png
# saved: plots/cfimdb_rdrop_alpha_best_dev_f1_sweep.png
# skip cfimdb  / rdrop_alpha: only one value
# skip SST / warmup_ratio: only one value
# skip cfimdb / warmup_ratio: only one value
# skip cfimdb  / warmup_ratio: only one value
# saved: plots/SST_weight_decay_best_dev_f1_sweep.png
# saved: plots/cfimdb_weight_decay_best_dev_f1_sweep.png
# skip cfimdb  / weight_decay: only one value
# skip SST / max_grad_norm: only one value
# skip cfimdb / max_grad_norm: only one value
# skip cfimdb  / max_grad_norm: only one value
# saved: plots/SST_rdrop_use_best_dev_f1_box.png
# saved: plots/cfimdb_rdrop_use_best_dev_f1_box.png
# skip cfimdb  / rdrop_use: only one value
# saved: plots/SST_warmup_use_best_dev_f1_box.png
# saved: plots/cfimdb_warmup_use_best_dev_f1_box.png
# skip cfimdb  / warmup_use: only one value
# saved: plots/SST_scheduler_use_best_dev_f1_box.png
# saved: plots/cfimdb_scheduler_use_best_dev_f1_box.png
# skip cfimdb  / scheduler_use: only one value
# saved: plots/SST_pooling_config_cat_best_dev_f1_box.png
# saved: plots/cfimdb_pooling_config_cat_best_dev_f1_box.png
# skip cfimdb  / pooling_config_cat: only one value
# saved: plots/SST_simple_classifier_use_best_dev_f1_box.png
# saved: plots/cfimdb_simple_classifier_use_best_dev_f1_box.png
# skip cfimdb  / simple_classifier_use: only one value
# saved: plots/SST_weight_decay_use_best_dev_f1_box.png
# saved: plots/cfimdb_weight_decay_use_best_dev_f1_box.png
# skip cfimdb  / weight_decay_use: only one value
# saved: plots/SST_grad_clip_use_best_dev_f1_box.png
# saved: plots/cfimdb_grad_clip_use_best_dev_f1_box.png
# skip cfimdb  / grad_clip_use: only one value
# saved: plots/SST_acc_f1_gap.png
# saved: plots/cfimdb_acc_f1_gap.png
# saved: plots/cfimdb _acc_f1_gap.png
